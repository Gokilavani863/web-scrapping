# %%
import requests

url = ('https://www.flipkart.com/ninety-one-meraki-s7-29t-shimano-gear-matt-grey-29-inches-7-lithium-ion-li-ion-electric-cycle/p/itm373adf91aa64f?pid=ECYGKRZKNDEHAVNX&lid=LSTECYGKRZKNDEHAVNXVWBJM4&marketplace=FLIPKART&store=abc%2Fulv%2Ftwp&srno=b_1_6&otracker=hp_omu_Beauty%252C%2BFood%252C%2BToys%2B%2526%2Bmore_3_7.dealCard.OMU_WEWB23EJNGV0_5&otracker1=hp_omu_PINNED_neo%2Fmerchandising_Beauty%252C%2BFood%252C%2BToys%2B%2526%2Bmore_NA_dealCard_cc_3_NA_view-all_5&fm=neo%2Fmerchandising&iid=1c3baa7d-c06c-4655-908c-4bf013dd5a8e.ECYGKRZKNDEHAVNX.SEARCH&ppt=browse&ppn=browse&ssid=xuat195zf40000001687156108913')
r = requests.get(url)
print(r.text)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.
# ...

# %%
print(r.status_code)
# Out:
# 200

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text,'html.parser')

# %%
title = soup.find('span',{'class':'B_NuCI'}).text.strip()
print(title)
# Out:
# Ninety one Meraki S7 29T with Shimano Gear - Matt Grey 29 inches 7 Gear Lithium-ion (Li-ion) Electric Cycle

# %%
price = soup.find('div',{'class':'_30jeq3 _16Jk6d'}).text.strip()
print(price)
# Out:
# ₹37,969

# %%
Rating = soup.find('div',{'class':'_3LWZlK'}).text.strip()
print(Rating)
# Out:
# 3.8

# %%
Specifications = soup.find('div',{'class':'_1UhVsV'}).text.strip()
print(Specifications)
# Out:
# GeneralModel NameMeraki S7 29T with Shimano Gear - Matt GreyBrand ColorMatt GreyTireNylonDimensionsWidth25 cmHeight84 cmDepth148 cmWeight31.4 kgBatteryBattery Capacity6.36 AhBattery Life2000 cyclesBattery Voltage36 VBattery TypeLithium-ion (Li-ion)WarrantyDomestic Warranty1 YearNot Covered in WarrantyPlastic Material

# %%
for x in Specifications:
    print(Specifications)
    break
# Out:
# GeneralModel NameMeraki S7 29T with Shimano Gear - Matt GreyBrand ColorMatt GreyTireNylonDimensionsWidth25 cmHeight84 cmDepth148 cmWeight31.4 kgBatteryBattery Capacity6.36 AhBattery Life2000 cyclesBattery Voltage36 VBattery TypeLithium-ion (Li-ion)WarrantyDomestic Warranty1 YearNot Covered in WarrantyPlastic Material

# %%
Specifications = soup.find_all('div',{'class':'CXW8mj _3nMexc'})
print(Specifications)
# Out:
# [<div class="CXW8mj _3nMexc" style="height:inherit;width:inherit"><img alt="Ninety one Meraki S7 29T with Shimano Gear - Matt Grey 29 inches 7 Gear Lithium-ion (Li-ion) Electric Cycle" class="_396cs4 _2amPTt _3qGmMb" loading="eager" src="https://rukminim1.flixcart.com/image/416/416/xif0q/electric-cycle/4/r/s/meraki-s7-29t-with-shimano-gear-matt-grey-matt-grey-18-5-ninety-original-imagkrzkdzfdjgrd.jpeg?q=70" srcset="https://rukminim1.flixcart.com/image/832/832/xif0q/electric-cycle/4/r/s/meraki-s7-29t-with-shimano-gear-matt-grey-matt-grey-18-5-ninety-original-imagkrzkdzfdjgrd.jpeg?q=70 2x, https://rukminim1.flixcart.com/image/416/416/xif0q/electric-cycle/4/r/s/meraki-s7-29t-with-shimano-gear-matt-grey-matt-grey-18-5-ninety-original-imagkrzkdzfdjgrd.jpeg?q=70 1x"/></div>]

# %%
r.status_code
# Out:
# 200

# %%
for item in soup.find_all('img'):
    print(item['src'])
# Out:
# //static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png
# //static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png
# https://rukminim1.flixcart.com/image/128/128/xif0q/electric-cycle/4/r/s/meraki-s7-29t-with-shimano-gear-matt-grey-matt-grey-18-5-ninety-original-imagkrzkdzfdjgrd.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/xif0q/electric-cycle/g/o/q/meraki-s7-29t-with-shimano-gear-matt-grey-matt-grey-18-5-ninety-original-imagkrzkgyfawxpe.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/xif0q/electric-cycle/y/m/e/meraki-s7-29t-with-shimano-gear-matt-grey-matt-grey-18-5-ninety-original-imagkrzk7fbznphr.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/xif0q/electric-cycle/r/w/s/meraki-s7-29t-with-shimano-gear-matt-grey-matt-grey-18-5-ninety-original-imagkrzkptkvd2kn.jpeg?q=70
# ...

# %%
for images in item:
    webs = requests.get(images)
    open('images/' + image.split('/n')[-1], 'wb').write(webs.content)
